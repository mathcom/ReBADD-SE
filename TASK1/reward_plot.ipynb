# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
REBADD_LIB_PATH = os.path.abspath(os.pardir)
if REBADD_LIB_PATH not in sys.path:
    sys.path = [REBADD_LIB_PATH] + sys.path

from ReBADD_config import hard_sigmoid, softplus
from rebadd.reinforce import gelu

# %%
sns.set_theme(style='whitegrid')

# %%
X = np.arange(0, 1.01, 0.01)
Y = softplus(X, 10, -0.5)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
X = np.arange(0, 10.01, 0.01)
Y = hard_sigmoid(X)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
X = np.arange(-5, 5.1, 0.01)
Y = gelu(X)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
softplus([0.5, 0.5, 0.6], 10, -0.5)
# Out:
# array([0.69314718, 0.69314718, 1.31326169])

# %%
hard_sigmoid([4.])
# Out:
# array([1.])

# %%
np.prod(softplus([0.5, 0.5, 0.6], 10, -0.5))
# Out:
# 0.6309605358314332

# %%
softplus([0.74, 0.34, 0.755], 10, -0.5)
# Out:
# array([2.48683615, 0.18390074, 2.62518323])

# %%
np.prod(softplus([0.74, 0.34, 0.755], 10, -0.5))
# Out:
# 1.2005776986737906

# %%
np.prod(softplus([0.64, 0.47, 0.729], 10, -0.5))
# Out:
# 2.1437264905088744

# %%
np.prod(softplus([0.87, 0.57, 0.5], 10, -0.5))
# Out:
# 2.8479555327595008

# %%
np.prod(softplus([0.23, 0.18, 0.778], 10, -0.5))
# Out:
# 0.007380822372113993

# %%
softplus([0.55, 0.56, 0.57], 10, -0.5)
# Out:
# array([0.97407698, 1.03748795, 1.10318605])
