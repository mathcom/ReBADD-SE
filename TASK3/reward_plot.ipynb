# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
REBADD_LIB_PATH = os.path.abspath(os.pardir)
if REBADD_LIB_PATH not in sys.path:
    sys.path = [REBADD_LIB_PATH] + sys.path

from ReBADD_config import hard_sigmoid, softplus
from rebadd.reinforce import gelu

# %%
N = 1000

np.log(N)
# Out:
# 6.907755278982137

# %%
sns.set_theme(style='whitegrid')

# %%
X = np.arange(0, 1.01, 0.01)
Y = softplus(X, 10, -0.5)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
X = np.arange(0, 10.01, 0.1)
Y = softplus(X, 2, -7.5)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
softplus([9.7, 7.5], 2, -7.5)
# Out:
# array([4.41220258, 0.69314718])

# %%
X = np.arange(0, 10.01, 0.1)
Y = softplus(X, 2, -7.)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
softplus([6.8], 2, -7.)
# Out:
# array([0.51301525])

# %%
X = np.arange(0, 10.01, 0.01)
Y = hard_sigmoid(X)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
X = np.arange(-5, 5.1, 0.01)
Y = gelu(X)

fig, ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(X, Y)
plt.show()

# %%
np.min(Y)
# Out:
# -0.17003944483437983
